# %% [markdown]
# #### Mini Project:Heart Attack Dataset using Desicion Tree

# %% [markdown]
# ### Problem Statement:
# The Heart Attack Dataset contains medical records and health metrics used to analyze risk factors for heart disease. It includes attributes like age, cholesterol levels, blood pressure, and lifestyle habits to support predictive modeling.

# %% [markdown]
# #### Data Collection:

# %% [markdown]
# #### Use the Kaggle Heart Attack Dataset which contains. Download if from Kaggle.
# https://www.kaggle.com/datasets/fatemehmohammadinia/heart-attack-dataset-tarik-a-rashid

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Dell\Downloads\hemavarshini\archive (6)\Medicaldataset.csv")

# %%
data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
data.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %%
data.tail()
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 1314                        67        204.0   1.63     0.006  negative
# 1315                        55        149.0   1.33     0.172  positive
# 1316                       104         96.0   1.24     4.250  positive
# 1317                        68        443.0   5.80     0.359  positive
# 1318                        79        134.0  50.89     1.770  positive

# %%
data.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
data.isnull()
# Out:
#         Age  Gender  Heart rate  Systolic blood pressure  \
# 0     False   False       False                    False
# 1     False   False       False                    False
# 2     False   False       False                    False
# 3     False   False       False                    False
# 4     False   False       False                    False
# ...     ...     ...         ...                      ...
# 1314  False   False       False                    False
# 1315  False   False       False                    False
# 1316  False   False       False                    False
# 1317  False   False       False                    False
# 1318  False   False       False                    False
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result
# 0                        False        False  False     False   False
# 1                        False        False  False     False   False
# 2                        False        False  False     False   False
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317    False
# 1318    False
# Length: 1319, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Heart rate', 'Systolic blood pressure',
#        'Diastolic blood pressure', 'Blood sugar', 'CK-MB', 'Troponin',
#        'Result'],
#       dtype='object')

# %% [markdown]
# #### Data Visualization

# %% [markdown]
# #### Matplotlib

# %%
import matplotlib.pyplot as plt

plt.plot(data['Heart rate'], data['Blood sugar'], marker='o', label='Medicaldataset')
plt.xlabel('Heart rate')
plt.ylabel('Blood sugar	')
plt.title('Medicaldataset (Matplotlib)')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Bar Chart

# %%
avg_radius_worst = data.groupby('Blood sugar')['Heart rate'].mean()
plt.bar(avg_radius_worst.index, avg_radius_worst)
plt.xlabel('Blood sugar')
plt.ylabel('Heart rate')
plt.title('Heart rate by Blood sugar (Matplotlib)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

if 'Troponin' in data.columns:
 sns.scatterplot(x='Age', y='Heart rate', hue='Troponin', data=data)
 plt.title('Age vs. Heart rate (Seaborn)')
 plt.show()

# %% [markdown]
# #### Plotly Visualization

# %%
import plotly.express as px

fig = px.bar(data, x='Heart rate', y='Troponin', 
             title='Heart rate and Troponin of the Breast Cancer (Plotly)', barmode='group')
fig.update_traces(marker_color='green') 
fig.show()

# %%
import plotly.express as px

fig = px.line(data, x='Age', y='Troponin', 
              title='Age vs Troponin levels (Plotly)')
fig.show()

# %% [markdown]
# #### Histogram

# %%
#histogram
sns.histplot(data["Systolic blood pressure"], color="brown")
plt.title("Systolic blood pressure")
plt.show()

# %% [markdown]
# #### Box Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=data["Systolic blood pressure"], color="orange")
plt.title("Systolic blood pressure")
plt.show()

# %% [markdown]
# #### Line Plot

# %%
#lineplot
plt.plot(data["Systolic blood pressure"], data["Troponin"], color="green")
plt.title("Medicaldataset")
plt.show()

# %% [markdown]
# #### Box Plot

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Systolic blood pressure',y='Troponin',data=data,palette='winter')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5424\1932621155.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Systolic blood pressure', ylabel='Troponin'>

# %% [markdown]
# ##### Pair Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Dell\Downloads\hemavarshini\archive (6)\Medicaldataset.csv") 

print(data.columns)

sns.pairplot(data, vars=['Troponin', 'Heart rate', 'Blood sugar', 'Diastolic blood pressure'], hue='Systolic blood pressure', palette='coolwarm')

plt.suptitle('Pair Plots of Selected Features')  
plt.show()
# Out:
# Index(['Age', 'Gender', 'Heart rate', 'Systolic blood pressure',
#        'Diastolic blood pressure', 'Blood sugar', 'CK-MB', 'Troponin',
#        'Result'],
#       dtype='object')

# %% [markdown]
# ### Desicion Tree

# %%
X = data[['Age', 'Gender','Heart rate', 'Systolic blood pressure', 'Blood sugar',]]	
y = data['Heart rate']

# %%
X
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  Blood sugar
# 0      64       1          66                      160        160.0
# 1      21       1          94                       98        296.0
# 2      55       1          64                      160        270.0
# 3      64       1          70                      120        270.0
# 4      55       1          64                      112        300.0
# ...   ...     ...         ...                      ...          ...
# 1314   44       1          94                      122        204.0
# 1315   66       1          84                      125        149.0
# 1316   45       1          85                      168         96.0
# 1317   54       1          58                      117        443.0
# 1318   51       1          94                      157        134.0
#
# [1319 rows x 5 columns]

# %%
y
# Out:
# 0       66
# 1       94
# 2       64
# 3       70
# 4       64
#         ..
# 1314    94
# 1315    84
# 1316    85
# 1317    58
# 1318    94
# Name: Heart rate, Length: 1319, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
X_train
# Out:
#      Age  Gender  Heart rate  Systolic blood pressure  Blood sugar
# 8     44       0          60                      154        135.0
# 848   69       1         119                      113        102.0
# 366   65       0          59                      183        119.0
# 608   50       1          65                      106        126.0
# 488   40       0          67                      101        258.0
# ..   ...     ...         ...                      ...          ...
# 575   52       1          63                      105         95.0
# 973   36       1          81                      135         93.0
# 75    57       1          94                       95        392.0
# 599   71       1          82                      138         96.0
# 863   60       1          82                      135        100.0
#
# [791 rows x 5 columns]

# %%
X_test
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  Blood sugar
# 980    65       1          62                       76        113.0
# 446    55       1          71                      137         94.0
# 874    48       0          64                      140        168.0
# 1279   55       0          73                      138        105.0
# 629    73       1          91                       91        274.0
# ...   ...     ...         ...                      ...          ...
# 682    68       1         135                       98         96.0
# 743    49       1          85                      119         35.0
# 1207   50       0          82                      108         77.0
# 464    63       0          69                      166        160.0
# 985    62       1          89                      116        149.0
#
# [528 rows x 5 columns]

# %%
y_train
# Out:
# 8       60
# 848    119
# 366     59
# 608     65
# 488     67
#       ...
# 575     63
# 973     81
# 75      94
# 599     82
# 863     82
# Name: Heart rate, Length: 791, dtype: int64

# %%
y_test
# Out:
# 980      62
# 446      71
# 874      64
# 1279     73
# 629      91
#        ...
# 682     135
# 743      85
# 1207     82
# 464      69
# 985      89
# Name: Heart rate, Length: 528, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
data = DecisionTreeClassifier()

# %%
data.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = data.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn import tree

# %%
plt.figure(figsize=(10, 8))
tree.plot_tree(data, filled=True)
plt.show()
